# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing Housing Dataset

# %%
df = pd.read_csv('housing.csv')
df
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 0    6.575   4.98     15.3  504000.0
# 1    6.421   9.14     17.8  453600.0
# 2    7.185   4.03     17.8  728700.0
# 3    6.998   2.94     18.7  701400.0
# 4    7.147   5.33     18.7  760200.0
# ..     ...    ...      ...       ...
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0
#
# [489 rows x 4 columns]

# %% [markdown]
# # Data Understanding

# %%
df.shape
# Out:
# (489, 4)

# %%
df.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %%
df.tail()
# Out:
#         RM  LSTAT  PTRATIO      MEDV
# 484  6.593   9.67     21.0  470400.0
# 485  6.120   9.08     21.0  432600.0
# 486  6.976   5.64     21.0  501900.0
# 487  6.794   6.48     21.0  462000.0
# 488  6.030   7.88     21.0  249900.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   RM       489 non-null    float64
#  1   LSTAT    489 non-null    float64
#  2   PTRATIO  489 non-null    float64
#  3   MEDV     489 non-null    float64
# dtypes: float64(4)
# memory usage: 15.4 KB

# %%
df.describe()
# Out:
#                RM       LSTAT     PTRATIO          MEDV
# count  489.000000  489.000000  489.000000  4.890000e+02
# mean     6.240288   12.939632   18.516564  4.543429e+05
# std      0.643650    7.081990    2.111268  1.653403e+05
# min      3.561000    1.980000   12.600000  1.050000e+05
# 25%      5.880000    7.370000   17.400000  3.507000e+05
# 50%      6.185000   11.690000   19.100000  4.389000e+05
# 75%      6.575000   17.120000   20.200000  5.187000e+05
# max      8.398000   37.970000   22.000000  1.024800e+06

# %% [markdown]
# Now we are exploring the dataset using plots

# %%
sns.pairplot(df)

# %% [markdown]
# we see that pairplot distribution of RM is in normalized form as we see the histogram of RM in bell shape.
#
# Also we see that the relation between RM and MEDV is quite linear.

# %%
df.plot(x = 'RM', y = 'MEDV', style= '*')
plt.title('Housing dataset')
plt.xlabel('RM')
plt.ylabel('MEDV')
plt.show()

# %%
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
X = df[['RM','LSTAT','PTRATIO']]           #features
y = df['MEDV']                             #our targeted variable

# %% [markdown]
# # Splitting the Data into Training & Testing

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# cheat note: if we type 'train_test_split' and press shift+tab, then we can see how many variables we can import in this function.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#         RM  LSTAT  PTRATIO
# 37   5.850   8.77     19.2
# 157  6.943   4.59     14.7
# 456  6.980  11.66     20.2
# 118  5.872  15.37     17.8
# 114  6.254  10.45     17.8
# ..     ...    ...      ...
# 106  5.836  18.66     20.9
# 270  7.820   3.76     14.9
# 348  6.112  12.67     20.2
# 435  6.297  17.27     20.2
# 102  6.405  10.63     20.9
#
# [327 rows x 3 columns]

# %% [markdown]
# # Training Algorithm

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()                      #creating a varible and storing object in it that is LinearRegression

# %%
regressor.fit(X_train, y_train)                     #We fit the model into training
# Out:
# LinearRegression()

# %% [markdown]
# # Predicting the Model

# %%
predictions = regressor.predict(X_test)

# %%
plt.scatter(y_test, predictions)

# %%
print(X_test)
y_pred = regressor.predict(X_test)
# Out:
#         RM  LSTAT  PTRATIO
# 451  5.926  18.13     20.2
# 84   6.389   9.62     18.5
# 434  6.655  17.73     20.2
# 472  5.414  23.97     20.1
# 428  6.459  23.98     20.2
# ..     ...    ...      ...
# 225  8.247   3.95     17.4
# 26   5.813  14.81     21.0
# 7    6.172  19.15     15.2
# 444  6.376  14.65     20.2
# 108  6.474  12.27     20.9
#
# [162 rows x 3 columns]

# %%
y_pred
# Out:
# array([344666.54868658, 505130.65378897, 411431.55887871, 241870.29479875,
#        329614.93975955, 403756.33319718, 264735.43363464, 696629.62144278,
#        364464.59774672, 583170.71671711, 456837.47473658, 367196.68221743,
#        269600.58655835, 269336.40630811, 386873.61436455, 524421.167396  ,
#        390149.07208782, 366909.28984758, 367153.26372466, 421016.83096944,
#        459575.92869444, 461426.8289403 , 371436.11460831, 640370.30935996,
#        467459.32528887, 473197.82392035, 497635.69972006, 631161.15355635,
#        675383.42873782, 174492.98573513, 513584.22963462, 243705.14161125,
#        535094.31682822, 507608.15411024, 307894.18855123, 501123.98935294,
#        629996.8068592 , 497089.23467121, 660039.24595655, 636496.07720081,
#        418654.18876471, 413540.7663637 , 323749.67735208, 454600.07550749,
#        393196.29903827, 580426.36822525, 356101.00058441, 393641.21148126,
# ...

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})         #comparing between test and predicted data
df
# Out:
#         Actual      Predicted
# 451   401100.0  344666.548687
# 84    501900.0  505130.653789
# 434   319200.0  411431.558879
# 472   147000.0  241870.294799
# 428   247800.0  329614.939760
# ..         ...            ...
# 225  1014300.0  744495.989556
# 26    348600.0  354319.764268
# 7     569100.0  449950.356711
# 444   371700.0  419495.481980
# 108   415800.0  439390.855617
#
# [162 rows x 2 columns]

# %% [markdown]
# # Evaluation of Model

# %% [markdown]
# ### Accuracy of the Model

# %%
from sklearn import metrics
metrics.r2_score(y_test, y_pred)
# Out:
# 0.7065680055196998

# %% [markdown]
# # Error Measure

# %%
print("Mean Square Error :", metrics.mean_squared_error(y_test,y_pred))
# Out:
# Mean Square Error : 7215564199.388882

# %%
print("Root Mean Square Error :", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Root Mean Square Error : 84944.47715648665

# %%
print("Mean Absolute Error :", metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error : 63436.77437291651
